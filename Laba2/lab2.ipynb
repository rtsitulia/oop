# %% [markdown]
# ## Знайомство з Пайтон

# %% [markdown]
# ### Базові типи змінних
# - стрічкові змінні

# %%
a = " Стрічка!"
print(a)
a #  буде виведено в комірці
# Out:
#  Стрічка!
# ' Стрічка!'

# %%
b = 'Це також стрічка'
c = '''
Стрічка 
з багаьох рядків
'''
print(a, b, c)
# Out:
#  Стрічка! Це також стрічка
# Стрічка
# з багаьох рядків

# %% [markdown]
# будь-які змінні в Пайтон будуть обєктами і ми можемо викликати атрибути та методи які характерні для даного обєкту

# %%
print(type(a))
print(a.upper())
# Out:
# <class 'str'>
#  СТРІЧКА!

# %% [markdown]
# стрічки можна зчеплювати одна з одною і така операція називається конкатенацією

# %%
a = "3"
b = "6"
print(a + b)
c = 3 # це вже цифра
print("Це зчеплення стрічок", a + str(c))
print("Це вже математична операція додавання чисел", int(a) + c)
# Out:
# 36
# Це зчеплення стрічок 33
# Це вже математична операція додавання чисел 6

# %% [markdown]
# ### Чисельні типи даних
# - int - цілочисельні дані
# - float - з плаваючою крапкою
# - при здійсненні арифметичних опереації де є float - результат також float
# - память яка виділяється комірці з змінною буде динамічно змінюватист

# %%
i = 3
print(type(i))
j = 1.1
print(type(j))
print(3 + i, 3 + j)

import sys
i += 10000000000
print(sys.getsizeof(i))
# Out:
# <class 'int'>
# <class 'float'>
# 6 4.1
# 32

# %% [markdown]
# ### Арифметичні операції
# - базові `+ - * /`
# - `//` - ціла частка від ділення `%` - дробова частка від ділення `**` - піднесення до степеня

# %%
print(5/2, 5//2, 5%2)
print(3**2)
# Out:
# 2.5 2 1
# 9

# %% [markdown]
# ### Колекції
# - найпростішою колекцією є `list`
# - накидана куча елементів, впорядкованих і кожен на своїх місцях
# - до кожного елемента ми можемо доступитись по індексу
# - в списках номерація починається з 0
# - відємні індекси, вказують на номерацію з кінця списку
# - ми можемо змінювати нас список
# - арифметичні операції над списками не працюють але можуть бути застосовані до елементів списку

# %%
l = [1, "1", 2, "2", "Два", [1, "Один"]]
print(l[0], l[3], l[-1])

l.append(6)
l.insert(0, "Початок")

l.remove("2")
l.pop(3)

print(l)
# Out:
# 1 2 [1, 'Один']
# ['Початок', 1, '1', 'Два', [1, 'Один'], 6]

# %% [markdown]
# - проімітуємо через списки здачу лабораторних студентами

# %%
s = ["Ааа", "Бббб", "Cccc"]
print("Група студентів які здають роботи: ", s)

s_pass = []

s_pass.append(s.pop(0))

print("Студенти які здали: ", s_pass, "\nСтуденти які залишились: ", s)
# Out:
# Група студентів які здають роботи:  ['Ааа', 'Бббб', 'Cccc']
# Студенти які здали:  ['Ааа']
# Студенти які залишились:  ['Бббб', 'Cccc']

# %% [markdown]
# - `dict` - колекція даних де дані знаходяться на іменних позиціях, або так званих Ключ=Значення пар
# - доступ до даних здійснюється по ключах
# - ключі завжди повинні бути унікальними
# - словники є змінними, їх можна модифікувати

# %%
d = {"name": 1, 1: "Один", "2": 2}

j = {
    "name": "Програма",
    "version": 1.2,
    "author": "Bohdan",
    "author": "Богдан"
}

print(d["2"], j["author"])
print(j)

import datetime
j["date"] = datetime.datetime.now()
print(j)
j["version"] = 1.3
j.pop("author")

print(j)
# Out:
# 2 Богдан
# {'name': 'Програма', 'version': 1.2, 'author': 'Богдан'}
# {'name': 'Програма', 'version': 1.2, 'author': 'Богдан', 'date': datetime.datetime(2024, 12, 8, 12, 21, 13, 25274)}
# {'name': 'Програма', 'version': 1.3, 'date': datetime.datetime(2024, 12, 8, 12, 21, 13, 25274)}

# %% [markdown]
# - `tuple` - набір даних які не можна змінювати після їх створення
# - елементи є впорядкованими

# %%
t = (2, "2", 6, 8, 2, 6)

print(t[0], "Кількість двійок: ", t.count(2))

l = list(t)
l.pop(0)
print("А тепре кількість 2: ", l.count(2))
# Out:
# 2 Кількість двійок:  2
# А тепре кількість 2:  1

# %% [markdown]
# - `set` - колекція унікальних елементів (немає повторів)
# - дані тут невпорядковані і ми не можемо витягнути саме те що ми хочемо (тут немає індеків)

# %%
t = (2, "2", 6, 8, 2, 6)
# знаходимо унікальні дані
s = set(t)
print(s)
s.remove(6)
print(s)
# Out:
# {8, '2', 2, 6}
# {8, '2', 2}

# %% [markdown]
# ### Розглядаємо вбудовані константи та функції
# - `None` є константа яка виражає відсутність значення
# - заререзвовані константи не можна перевизначати
# - дві булеві змінні True False є константами, і використовуються у логічних виразах
# - будь-яка величина в Пайтон вважається істинною, окрім `False`, `0`, `None`

# %%
def my_fun():
    return

print(my_fun())

true = False
print("Чому тут", true)

#None = False # це видасть помилку
# Out:
# None
# Чому тут False

# %% [markdown]
# ### Методи виводу
# - для виводу ми користувались вбудваною фінкцією print
# - ми передавали значення яке хочемо вивести

# %%
print("Ми", "хочемо", "вивести", "текст")
s = "Ми" + " " + "хочемо" + " " + "вивести" + " " + "текст"
print(s)

a = "Ми"
b = "хочемо"
c = "вивести"
d = "текст"
print(f"{a} {b} {c} {d}")
# Out:
# Ми хочемо вивести текст
# Ми хочемо вивести текст
# Ми хочемо вивести текст

# %% [markdown]
# ### Знайомиммось з циклами
# - `while` - умовний цикл, який буде виконуватись поки умова є істинною
# - `for` - ітераційний цикл - нам наперед відомо скільки циклів потрібно зробити
# - в реальних ситуаціях немає різниці який  циклів використовувати
# - в нас є фабрика яка виробляє M&Ms і пакує в пачки по 30 штук. Коли ми беремо пачку ми починаємо їсти M&Ms і здієнаємось їх кольори. Написати програму яка імітує даний процес.

# %%
mmd = ["червоний", "жовтий",  "оранжевий"]
factory = mmd * 100
print(f"На фабриці втготовили {len(factory)} M&Ms {factory}")
from random import shuffle

shuffle(factory)

# розсортовуємо M&Ms по пачкам
pack = []

i = 0 
while i < len(factory):
    pack = factory[i:i+27]
    print(f"Посортували в пачку {len(pack)}: {pack}")
    i += 6
# Out:
# На фабриці втготовили 300 M&Ms ['червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий']
# Посортували в пачку 27: ['жовтий', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'оранжевий']
# Посортували в пачку 27: ['оранжевий', 'червоний', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'жовтий', 'червоний', 'оранжевий']
# Посортували в пачку 27: ['червоний', 'червоний', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'жовтий']
# Посортували в пачку 27: ['жовтий', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний']
# Посортували в пачку 27: ['оранжевий', 'червоний', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий']
# Посортували в пачку 27: ['жовтий', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'жовтий', 'оранжевий', 'жовтий']
# Посортували в пачку 27: ['жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'жовтий', 'оранжевий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'жовтий', 'оранжевий', 'жовтий']
# Посортували в пачку 27: ['оранжевий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'жовтий', 'оранжевий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'жовтий', 'червоний', 'червоний', 'жовтий']
# Посортували в пачку 27: ['оранжевий', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'жовтий', 'оранжевий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'жовтий', 'червоний', 'червоний', 'жовтий', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий']
# Посортували в пачку 27: ['жовтий', 'оранжевий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'жовтий', 'червоний', 'червоний', 'жовтий', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'червоний']
# Посортували в пачку 27: ['жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'жовтий', 'червоний', 'червоний', 'жовтий', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'оранжевий', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний']
# Посортували в пачку 27: ['червоний', 'червоний', 'жовтий', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'оранжевий', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'червоний', 'жовтий']
# Посортували в пачку 27: ['жовтий', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'оранжевий', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'червоний', 'оранжевий', 'оранжевий']
# Посортували в пачку 27: ['жовтий', 'жовтий', 'червоний', 'оранжевий', 'оранжевий', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий']
# Посортували в пачку 27: ['оранжевий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'червоний']
# Посортували в пачку 27: ['жовтий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'оранжевий']
# Посортували в пачку 27: ['червоний', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий']
# Посортували в пачку 27: ['жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий']
# Посортували в пачку 27: ['жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий']
# Посортували в пачку 27: ['червоний', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'жовтий', 'жовтий']
# Посортували в пачку 27: ['оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий']
# Посортували в пачку 27: ['оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий']
# Посортували в пачку 27: ['червоний', 'червоний', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'жовтий']
# Посортували в пачку 27: ['оранжевий', 'жовтий', 'жовтий', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий']
# Посортували в пачку 27: ['червоний', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'оранжевий']
# Посортували в пачку 27: ['оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'оранжевий']
# Посортували в пачку 27: ['оранжевий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'червоний']
# Посортували в пачку 27: ['червоний', 'червоний', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'жовтий', 'червоний']
# Посортували в пачку 27: ['червоний', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'червоний']
# Посортували в пачку 27: ['жовтий', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий']
# Посортували в пачку 27: ['оранжевий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'оранжевий']
# Посортували в пачку 27: ['жовтий', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'жовтий']
# Посортували в пачку 27: ['оранжевий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'червоний', 'червоний', 'оранжевий']
# Посортували в пачку 27: ['червоний', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'червоний', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'оранжевий']
# Посортували в пачку 27: ['червоний', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'червоний', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'оранжевий', 'жовтий']
# Посортували в пачку 27: ['жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'червоний', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'жовтий']
# Посортували в пачку 27: ['червоний', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'червоний', 'червоний', 'жовтий']
# Посортували в пачку 27: ['жовтий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'червоний', 'червоний', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий']
# Посортували в пачку 27: ['оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'червоний', 'червоний', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'червоний']
# Посортували в пачку 27: ['червоний', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'червоний', 'червоний', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'оранжевий']
# Посортували в пачку 27: ['червоний', 'червоний', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'червоний']
# Посортували в пачку 27: ['оранжевий', 'жовтий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий']
# Посортували в пачку 27: ['жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'червоний', 'оранжевий']
# Посортували в пачку 27: ['оранжевий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий']
# Посортували в пачку 27: ['оранжевий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'оранжевий']
# Посортували в пачку 27: ['червоний', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий']
# Посортували в пачку 24: ['червоний', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'жовтий']
# Посортували в пачку 18: ['червоний', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'жовтий']
# Посортували в пачку 12: ['оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'жовтий']
# Посортували в пачку 6: ['червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'жовтий']

# %%
while pack:
    print(f"Витягуємо {pack.pop(0)} чіпси і зїли!")
# Out:
# Витягуємо червоний чіпси і зїли!
# Витягуємо жовтий чіпси і зїли!
# Витягуємо оранжевий чіпси і зїли!
# Витягуємо червоний чіпси і зїли!
# Витягуємо жовтий чіпси і зїли!
# Витягуємо жовтий чіпси і зїли!

# %%
np = int(len(factory) / 30) # скільки пачок вийде

for i in range(np):
    start = i*30
    stop = start + 30
    pack = factory[start:stop]
    print(f"Посортували в пачку {len(pack)}: {pack}")
# Out:
# Посортували в пачку 30: ['жовтий', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'жовтий', 'жовтий']
# Посортували в пачку 30: ['жовтий', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'жовтий', 'оранжевий', 'жовтий', 'червоний', 'жовтий', 'жовтий']
# Посортували в пачку 30: ['жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'жовтий', 'червоний', 'червоний', 'жовтий', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'оранжевий', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'оранжевий']
# Посортували в пачку 30: ['жовтий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'оранжевий']
# Посортували в пачку 30: ['оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'жовтий', 'жовтий', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'жовтий']
# Посортували в пачку 30: ['оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'жовтий', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'жовтий']
# Посортували в пачку 30: ['оранжевий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий']
# Посортували в пачку 30: ['жовтий', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'червоний', 'червоний', 'оранжевий', 'червоний', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний']
# Посортували в пачку 30: ['червоний', 'червоний', 'жовтий', 'червоний', 'червоний', 'оранжевий', 'оранжевий', 'жовтий', 'жовтий', 'жовтий', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'оранжевий', 'оранжевий', 'жовтий', 'червоний', 'жовтий', 'жовтий', 'червоний']
# Посортували в пачку 30: ['червоний', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'червоний', 'червоний', 'червоний', 'оранжевий', 'жовтий', 'жовтий', 'червоний', 'червоний', 'жовтий', 'жовтий', 'оранжевий', 'оранжевий', 'червоний', 'оранжевий', 'червоний', 'оранжевий', 'жовтий', 'оранжевий', 'червоний', 'червоний', 'жовтий', 'оранжевий', 'червоний', 'жовтий', 'жовтий']

# %%
for m in pack:
    print(f"Витягуємо {m} чіпси і зїли!")
# Out:
# Витягуємо червоний чіпси і зїли!
# Витягуємо жовтий чіпси і зїли!
# Витягуємо жовтий чіпси і зїли!
# Витягуємо оранжевий чіпси і зїли!
# Витягуємо оранжевий чіпси і зїли!
# Витягуємо червоний чіпси і зїли!
# Витягуємо червоний чіпси і зїли!
# Витягуємо червоний чіпси і зїли!
# Витягуємо оранжевий чіпси і зїли!
# Витягуємо жовтий чіпси і зїли!
# Витягуємо жовтий чіпси і зїли!
# Витягуємо червоний чіпси і зїли!
# Витягуємо червоний чіпси і зїли!
# Витягуємо жовтий чіпси і зїли!
# Витягуємо жовтий чіпси і зїли!
# Витягуємо оранжевий чіпси і зїли!
# Витягуємо оранжевий чіпси і зїли!
# Витягуємо червоний чіпси і зїли!
# Витягуємо оранжевий чіпси і зїли!
# Витягуємо червоний чіпси і зїли!
# Витягуємо оранжевий чіпси і зїли!
# Витягуємо жовтий чіпси і зїли!
# Витягуємо оранжевий чіпси і зїли!
# Витягуємо червоний чіпси і зїли!
# Витягуємо червоний чіпси і зїли!
# Витягуємо жовтий чіпси і зїли!
# Витягуємо оранжевий чіпси і зїли!
# Витягуємо червоний чіпси і зїли!
# Витягуємо жовтий чіпси і зїли!
# Витягуємо жовтий чіпси і зїли!

# %% [markdown]
# - ми граємо в гру де потрібно кидати кубик. Нам дано 3 спроби щоб викинути число 6
# - для модифікації виконання циклу існує 2 функції:
# - `break` - зупиняє цикл і виходить з нього
# - `contunue` - перериває поточну ітерацю циклу і йде на початок виконувати наступну ітерацію

# %%
from random import randint

for i in range(3):
    dice = randint(1, 6)
    print(f"Кинули кубик і нам випало число: {dice}")
    if dice == 6:
        print("Ура ми виграми!")
        break
    else:
        print("Спробуйте ще.")
# Out:
# Кинули кубик і нам випало число: 5
# Спробуйте ще.
# Кинули кубик і нам випало число: 4
# Спробуйте ще.
# Кинули кубик і нам випало число: 3
# Спробуйте ще.

# %%
i = 1
dice = None

while i <= 3 and dice != 6:
    dice = randint(1, 6)
    print(f"Кинули кубик і нам випало число: {dice}")
    i += 1

if dice == 6:
    print("Ура ми виграми!")
else:
    print("Використали всі спроби і програли.")
# Out:
# Кинули кубик і нам випало число: 2
# Кинули кубик і нам випало число: 4
# Кинули кубик і нам випало число: 3
# Використали всі спроби і програли.

# %% [markdown]
# ### Одностірчкові записи циклів
# - one-liners - дозволяють нам записати цикл не у канонічному вигляді а у вигляді однієї стрічки
# - такі записи можливі тільки коли ми створюмо Списки з використанням циклу `for`
# - не можемо таке робити з `while`

# %%
m = []
for i in range(5):
    m.append(f"{i}) ітерація")

print(m)
# Out:
# ['0) ітерація', '1) ітерація', '2) ітерація', '3) ітерація', '4) ітерація']

# %%
m = [f"{j}) ітерація" for j in range(5)]

print(m)

k = [x**2 + 5*x + 2 for x in range(-10, 10)]
print(k)
# Out:
# ['0) ітерація', '1) ітерація', '2) ітерація', '3) ітерація', '4) ітерація']
# [52, 38, 26, 16, 8, 2, -2, -4, -4, -2, 2, 8, 16, 26, 38, 52, 68, 86, 106, 128]

# %%
print("Ура ми виграми!" if dice == 6 else "Використали всі спроби і програли.")
# Out:
# Використали всі спроби і програли.

# %% [markdown]
# ### Розглядаємо виловлювання помилок
# - помилки можуть виникати, і нам ніщо не забороняє виконувати код з помилками
# - є помилки які не залежать від самої програми а залежать від якихось зовнішніх чинників
# - якщо ми знаємо що можливе виконання помилки нам потрібно якось її уникнути або опацювати так званий виняток
# - `finally` це дія яка виконається завжди не залежно від того чи є помилка чи ні
#
# ```python
# True = 1
# # Це видасть помилку SyntaxError: cannot assign to True
# ```

# %%
from random import randint

for n in range(30):
    x = randint(-10, 10)
    try:
        y = 7/x
    except ZeroDivisionError as e:
        # Це так званий обробник помилок
        y = f"Виникла помилка: {e}"

    print(f"{n+1}) При діленні 7 на {x} буде: {y}")
# Out:
# 1) При діленні 7 на 2 буде: 3.5
# 2) При діленні 7 на -10 буде: -0.7
# 3) При діленні 7 на -2 буде: -3.5
# 4) При діленні 7 на -5 буде: -1.4
# 5) При діленні 7 на 7 буде: 1.0
# 6) При діленні 7 на -6 буде: -1.1666666666666667
# 7) При діленні 7 на 1 буде: 7.0
# 8) При діленні 7 на -7 буде: -1.0
# 9) При діленні 7 на -2 буде: -3.5
# 10) При діленні 7 на -6 буде: -1.1666666666666667
# 11) При діленні 7 на -2 буде: -3.5
# 12) При діленні 7 на -5 буде: -1.4
# 13) При діленні 7 на 1 буде: 7.0
# 14) При діленні 7 на 0 буде: Виникла помилка: division by zero
# 15) При діленні 7 на 8 буде: 0.875
# 16) При діленні 7 на -2 буде: -3.5
# 17) При діленні 7 на -8 буде: -0.875
# 18) При діленні 7 на -3 буде: -2.3333333333333335
# 19) При діленні 7 на -3 буде: -2.3333333333333335
# 20) При діленні 7 на -1 буде: -7.0
# 21) При діленні 7 на -1 буде: -7.0
# 22) При діленні 7 на 5 буде: 1.4
# 23) При діленні 7 на -6 буде: -1.1666666666666667
# 24) При діленні 7 на -6 буде: -1.1666666666666667
# 25) При діленні 7 на 3 буде: 2.3333333333333335
# 26) При діленні 7 на 0 буде: Виникла помилка: division by zero
# 27) При діленні 7 на -4 буде: -1.75
# 28) При діленні 7 на -1 буде: -7.0
# 29) При діленні 7 на -5 буде: -1.4
# 30) При діленні 7 на 5 буде: 1.4

# %%
e = (ZeroDivisionError, TypeError, KeyError)
x = 0
try:
    y = 7/x
    d = {"b": 1}
    d["a"]
except e as p:
    print(f"Обробляємо виникшу помилку: {p}!")
# Out:
# Обробляємо виникшу помилку: division by zero!
